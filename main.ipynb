# %% [markdown]
# # Информация

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Что у нас в train:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Формат вывода:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Начало работы
