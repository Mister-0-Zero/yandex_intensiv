# %% [markdown]
# # Information

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Что там по структуре данных?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ожидаемый submission

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Study
